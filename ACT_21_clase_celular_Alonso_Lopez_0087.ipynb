# %% [markdown]
# <a href="https://colab.research.google.com/github/AlonsoLopezGarcia128/ACT-21-clase-celular-en-Python-FECHA-abril-2026/blob/main/ACT_21_clase_celular_Alonso_Lopez_0087.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Alonso Lopez Garcia NL = 31   Fecha 22/Abril/2026
# #### Clase celular
# ![texto del vínculo](https://raw.githubusercontent.com/AlonsoLopezGarcia128/ACT-21-clase-celular-en-Python-FECHA-abril-2026/refs/heads/main/infografiaclasecelular.png)

# %%
class Celular:
    # Constructor
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio

    # Método para mostrar información
    def mostrar_info(self):
        return f"{self.marca} {self.modelo} - ${self.precio}"

    def encender(self):
        print(f"El celular {self.marca} {self.modelo} está encendido.")

# Instanciar objetos
celular1 = Celular("Samsung", "Galaxy S23", 800)
celular2 = Celular("Apple", "iPhone 15", 1000)

print("Celular1 :")
print(celular1.mostrar_info())
celular1.encender()

print("Celular2 :")
print(celular2.mostrar_info())
celular2.encender()

print("Programa terminado")
print("Creador de software por Alonso Lopez Garcia NL = 31")
# Out:
# Celular1 :
# Samsung Galaxy S23 - $800
# El celular Samsung Galaxy S23 está encendido.
# Celular2 :
# Apple iPhone 15 - $1000
# El celular Apple iPhone 15 está encendido.
# Programa terminado
# Creador de software por Alonso Lopez Garcia NL = 31

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/AlonsoLopezGarcia128/ACT-21-clase-celular-en-Python-FECHA-abril-2026/refs/heads/main/Logicadefuncionamiento.png)
